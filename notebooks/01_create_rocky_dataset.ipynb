# %%
import pandas as pd
df = pd.read_csv("../data/clean_data.csv", comment='#')
# Out:
# C:\Users\20106\AppData\Local\Temp\ipykernel_3268\1482058725.py:2: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/clean_data.csv", comment='#')

# %%
df_rocky = df[df['pl_rade'] <= 2].copy()

# df['pl_masse'] > 0.5 & df ['pl_masse'] < 2

# %%
print("عدد الكواكب...", len(df))
print("عدد الكواكب...", len(df_rocky))
# Out:
# عدد الكواكب... 38973
# عدد الكواكب... 10913

# %%
df_rocky.to_csv(r"../outputs/rocky_planets_catalog.csv.csv", index=False)
