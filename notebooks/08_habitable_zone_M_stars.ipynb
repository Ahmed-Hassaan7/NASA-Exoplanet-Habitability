# %%
import pandas as pd
df = pd.read_csv("../data/clean_data.csv", comment='#')

# %%
df2 = df[(df['pl_orbsmax'] >= 0.1) & (df['pl_orbsmax'] <=0.3)]
df2.to_csv(r"../outputs/insights.csv", index=False)

# %%
df3=df2[(df2['pl_insol'] >= 0.5) & (df2['pl_insol'] <= 1.5)]
df3.to_csv(r"../outputs/insights.csv", index=False)

# %%
df3
# Out:
#      rowid    pl_name hostname pl_letter hd_name hip_name         tic_id  \
# 40    5174     K2-3 d     K2-3         d     NaN      NaN  TIC 173103335
# 42    5176     K2-3 d     K2-3         d     NaN      NaN  TIC 173103335
# 194  37126  TOI-700 d  TOI-700         d     NaN      NaN  TIC 150428135
# 195  37127  TOI-700 d  TOI-700         d     NaN      NaN  TIC 150428135
# 196  37129  TOI-700 e  TOI-700         e     NaN      NaN  TIC 150428135
#
#                       gaia_dr2_id                   gaia_dr3_id  default_flag  \
# 40   Gaia DR2 3796690380302214272  Gaia DR3 3796690380302214272             0
# 42   Gaia DR2 3796690380302214272  Gaia DR3 3796690380302214272             1
# 194  Gaia DR2 5284517766615492736  Gaia DR3 5284517766615850752             1
# 195  Gaia DR2 5284517766615492736  Gaia DR3 5284517766615850752             0
# 196  Gaia DR2 5284517766615492736  Gaia DR3 5284517766615850752             1
#
# ...

# %%
df3
# Out:
#      rowid    pl_name hostname pl_letter hd_name hip_name         tic_id  \
# 40    5174     K2-3 d     K2-3         d     NaN      NaN  TIC 173103335
# 42    5176     K2-3 d     K2-3         d     NaN      NaN  TIC 173103335
# 194  37126  TOI-700 d  TOI-700         d     NaN      NaN  TIC 150428135
# 195  37127  TOI-700 d  TOI-700         d     NaN      NaN  TIC 150428135
# 196  37129  TOI-700 e  TOI-700         e     NaN      NaN  TIC 150428135
#
#                       gaia_dr2_id                   gaia_dr3_id  default_flag  \
# 40   Gaia DR2 3796690380302214272  Gaia DR3 3796690380302214272             0
# 42   Gaia DR2 3796690380302214272  Gaia DR3 3796690380302214272             1
# 194  Gaia DR2 5284517766615492736  Gaia DR3 5284517766615850752             1
# 195  Gaia DR2 5284517766615492736  Gaia DR3 5284517766615850752             0
# 196  Gaia DR2 5284517766615492736  Gaia DR3 5284517766615850752             1
#
# ...
