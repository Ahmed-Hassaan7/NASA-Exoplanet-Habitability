# %%
import pandas as pd
df = pd.read_csv("../data/clean_data.csv", comment='#')

# %%
import sys
# !{sys.executable} -m pip install openpyxl

# %%
df.info()

# %%
df.describe()

# %%
pd.set_option('display.max_columns', 289)
pd.set_option('display.max_rows', 38973)
schema_df = pd.read_csv(r"../data/clean_data.csv", comment='#')
df = pd.read_csv
schema_df

# %%
df.columns

# %%
#  كل طريقة اكتشاف اتكررت كام مرة
df['discoverymethod'].value_counts()

# %%
# اقدم كوكب تم اكتشافه
df[['pl_name', 'disc_year']].sort_values('disc_year').head(1)

# %%
# احدث كوكب تم اكتشاقه
df[['pl_name', 'disc_year']].sort_values('disc_year').tail(1)

# %%
# كل سنه اكتشوف فيها كام كوكب
df.groupby("disc_year")["pl_name"].count()

# %%
# الكوكب اللي بيدور حولين شمسه اطول مده 

df2 = df["pl_orbper"].idxmax()
df.loc[df2]

# %%
# الكوكب اللي بيدور حولين شمسه اقصر مده 
df2 = df["pl_orbper"].idxmin()
df.loc[df2]

# %%
df[['pl_name', 'disc_year']].sort_values('disc_year').tail(1)

# %%
df[['pl_name', 'disc_year']].sort_values('disc_year').head(1)
