# %%
import pandas as pd
df = pd.read_csv("../data/clean_data.csv", comment='#')

# %%
df.head(10)

# %%
df.tail(10)

# %%
df.info()

# %%
df.columns

# %%
df.describe()

# %%
df["pl_name"]

# %%
df[['pl_name', 'disc_year']]

# %%
# df[df['disc_year']>2020][['pl_name', "disc_year"]]
df[df['disc_year']>2020].filter(['pl_name', 'disc_year'])

# %%
# discoverymethod
df[df['discoverymethod'] == 'Transit'].filter(['pl_name', 'discoverymethod'])

# %%
df[(df['discoverymethod'] == 'Transit') & (df['pl_masse'] < 1)].filter(['pl_name', 'discoverymethod', 'pl_masse'])

# %%
df[(df['discoverymethod'] == 'Transit') & (df['pl_masse'] < 1)].filter(['pl_name', 'discoverymethod', 'pl_masse']).sort_values(by = 'pl_masse', ascending= False).head(5)

# %%
df[(df['discoverymethod'] == 'Transit') & (df['pl_masse'] < 1)].filter(['pl_name', 'discoverymethod', 'pl_masse', 'pl_orbper']).sort_values(by = 'pl_orbper',ascending= False)
